# %% [markdown]
# <a href="https://colab.research.google.com/github/vaish2814/FASTAPI_TASK_03/blob/main/Task_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install "fastapi==0.110.0" "uvicorn==0.23.2" "pyngrok==7.0.0"

# %%
from fastapi import FastAPI

app = FastAPI()

@app.get("/")
def home():
    return {"message": "FastAPI running"}

@app.get("/products")
def products():
    return [
        {"id":1,"name":"Mouse","price":500},
        {"id":2,"name":"Keyboard","price":800}
    ]

# %%
from pyngrok import ngrok

ngrok.kill()

public_url = ngrok.connect(8000)
print("Public URL:", public_url)
# Out:
# WARNING:pyngrok.process.ngrok:t=2026-03-11T18:20:40+0000 lvl=warn msg="ngrok config file found at both XDG and legacy locations, using XDG location" xdg_path=/root/.config/ngrok/ngrok.yml legacy_path=/root/.ngrok2/ngrok.yml
# Public URL: NgrokTunnel: "https://isosmotic-costlier-wenona.ngrok-free.dev" -> "http://localhost:8000"

# %%
import uvicorn
from uvicorn import Config, Server

config = Config(app=app, host="0.0.0.0", port=8000, log_level="info")
server = Server(config)

await server.serve()
# Out:
# INFO:     Started server process [2177]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# INFO:     58.84.61.19:0 - "GET / HTTP/1.1" 200 OK
# INFO:     58.84.61.19:0 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# INFO:     58.84.61.19:0 - "GET / HTTP/1.1" 200 OK
# INFO:     58.84.61.19:0 - "GET /docs HTTP/1.1" 200 OK
# INFO:     58.84.61.19:0 - "GET /openapi.json HTTP/1.1" 200 OK
# INFO:     58.84.61.19:0 - "GET /docs HTTP/1.1" 200 OK
# INFO:     58.84.61.19:0 - "GET /openapi.json HTTP/1.1" 200 OK
# INFO:     58.84.61.19:0 - "GET /products HTTP/1.1" 200 OK
# INFO:     58.84.61.19:0 - "GET / HTTP/1.1" 200 OK
